# %% [markdown]
# # Cluster product descriptions into similar groups by using NLP techinque

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Omkar\Downloads\Myntra dataset\Myntra fashion\Myntra Fasion Clothing.csv")
data
# Out:
# C:\Users\Omkar\AppData\Local\Temp\ipykernel_8684\1859380839.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r"C:\Users\Omkar\Downloads\Myntra dataset\Myntra fashion\Myntra Fasion Clothing.csv")
#                                                       URL  Product_id  \
# 0       https://www.myntra.com/jeans/roadster/roadster...     2296012
# 1       https://www.myntra.com/track-pants/locomotive/...    13780156
# 2       https://www.myntra.com/shirts/roadster/roadste...    11895958
# 3       https://www.myntra.com/shapewear/zivame/zivame...     4335679
# 4       https://www.myntra.com/tshirts/roadster/roadst...    11690882
# ...                                                   ...         ...
# 526559  https://www.myntra.com/sweaters/hm/hm-women-be...    16929990
# 526560  https://www.myntra.com/jackets/hm/hm-women-bla...    16026012
# 526561  https://www.myntra.com/dresses/250-designs/250...    17654114
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

documents = data['Description'].values.astype("U")

vectorizer = TfidfVectorizer(stop_words='english')
features = vectorizer.fit_transform(documents)

# %%
k = 20
model = KMeans(n_clusters=k, init='k-means++', max_iter=100, n_init=1)
model.fit(features)
data['cluster'] = model.labels_
data.head()
# Out:
#                                                  URL  Product_id   BrandName  \
# 0  https://www.myntra.com/jeans/roadster/roadster...     2296012    Roadster
# 1  https://www.myntra.com/track-pants/locomotive/...    13780156  LOCOMOTIVE
# 2  https://www.myntra.com/shirts/roadster/roadste...    11895958    Roadster
# 3  https://www.myntra.com/shapewear/zivame/zivame...     4335679      Zivame
# 4  https://www.myntra.com/tshirts/roadster/roadst...    11690882    Roadster
#
#                 Category Individual_category category_by_Gender  \
# 0            Bottom Wear               jeans                Men
# 1            Bottom Wear         track-pants                Men
# 2                Topwear              shirts                Men
# 3  Lingerie & Sleep Wear           shapewear              Women
# 4                Western             tshirts              Women
#
#                                          Description  DiscountPrice (in Rs)  \
# ...

# %%
# output the result to a text file.

clusters = data.groupby('cluster')    

for cluster in clusters.groups:
    f = open('cluster'+str(cluster)+ '.csv', 'w') # create csv file
    data = clusters.get_group(cluster)[['Individual_category','Description']] # get title and overview columns
    f.write(data.to_csv(index_label='id')) # set index to id
    f.close()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
print("Cluster centroids: \n")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms  = vectorizer.get_feature_names_out()

for i in range(k):
    print("Cluster %d:" % i)
    for j in order_centroids[i, :10]: #print out 10 feature terms of each cluster
        print (' %s' % terms[j])
    print('------------')
# Out:
# Cluster centroids:
#
# Cluster 0:
#  women
#  solid
#  black
#  dress
#  white
#  green
#  printed
#  pack
#  pink
#  men
# ------------
# Cluster 1:
#  ethnic
#  motifs
#  kurta
#  printed
#  women
#  basket
#  crepe
#  pack
#  palazzos
#  multicoloured
# ------------
# Cluster 2:
#  casual
#  shirt
#  fit
#  men
#  slim
#  checked
#  blue
#  cotton
#  printed
#  white
# ------------
# Cluster 3:
#  coloured
#  peach
#  cream
#  women
#  saree
#  kurta
#  printed
#  floral
#  cotton
#  pothys
# ------------
# Cluster 4:
#  nehru
#  jacket
#  churidar
#  kurta
#  men
#  sojanya
#  woven
#  solid
#  design
#  deyann
# ------------
# Cluster 5:
#  heusen
#  van
#  men
#  woman
#  fit
#  slim
#  sport
#  formal
#  trousers
#  shirt
# ------------
# Cluster 6:
#  night
#  suit
#  women
#  printed
#  white
#  blue
#  pink
#  black
#  cotton
#  dreams
# ------------
# Cluster 7:
#  bra
#  padded
#  non
#  lightly
#  wired
#  everyday
#  pack
#  zivame
#  solid
#  underwired
# ------------
# ...
